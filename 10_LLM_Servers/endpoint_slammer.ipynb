# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
# model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
model_endpoint = "accounts/pembeweb-1y8syz8lwqd/deployments/qo3w9ebm"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# The old tongue‑twister is a bit more than a playful rhyme—it’s also a broad‑brush way to ask, “What would a woodchuck’s wood‑chucking capacity look like if it actually chuck‑d wood?” In reality, *Marmota monax* (the woodchuck, or ground squirrel) isn’t a wood‑chuck at all—its diet is greens, but we can still have a little fun with numbers.
#
# ### The “Literally” Field
#
# 1. **What does “chuck” mean?**
#    In this context it’s generally understood as “to throw, move, or transport.”
# 2. **What would they be chocking?**
#    Not logs in the classic sense, but small branches, sticks, or chunks of wood it could move.
#
# 3. **Rockefellor & Workman (1968)** – no study, but a quick dimensional analysis:
#    * A woodchuck moves its mass about 10–20 kg in burrowing breaks.
#    * If “chucking” involved moving wood with similar strength, the volume could be roughly 0.5–1 m³ of loosely packed wood (about 250–500 kg of small branches).
#
# ### The “Just for Fun” Answer
#
# The folk‑scholar (and most folklore‑based) answer is often quoted as **700‑pounds of wood** (≈ 317 kg), come from a 1909 *New York Times* piece that joked:
#
# > “A wood‑chuck would chuck much, and if a wood‑chuck could chuck wood, you might expect it to chuck the amount that matches the weight of a standard load a work‑horse can drag—roughly 700 lb.”
#
# It’s just a number that rhymes with **“towers”** and fits **“moo”**‑like rhythm—it’s not being measured on a scale somewhere in a laboratory.
#
# ### Bottom Line
#
# - **Real woodchucks** chuck (move) dirt, not wood. Their burrowing prowess is impressive but mostly earth‑focusing.
# - **The classic tongue‑twister** is a rhyme, not a scientific inquiry, and the 700‑pound “answer” is as playful as it is poetic.
# - **If a woodchuck *could* chuck wood**, the best one can truly say is: it would chuck a *lot*. 😄
#
# So, the result is: **about 700 pounds of wood—just enough to clear a small forest—or, more realistically, a woodchuck will only move dirt in its burrow, and that’s all we have concrete evidence for.**

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 3: A good old‑fashioned answer to the age‑old riddle goes like ...
# Response 18: A woodchuck (also known as a groundhog) doesn’t actually chu...
# Response 21: A classic response to that tongue‑twister goes like this:
#
# >...
# Response 12: A classic tongue‑twister that never really has a single “rig...
# Response 23: Classic tongue‑twist time! While the rhyme itself is just a ...
# Response 13: Folklore says a woodchuck would chuck about 700 pounds of wo...
# Response 24: A wood‑chuck wouldn’t actually chuck any timber at all—but w...
# Response 1: A woodchuck would chuck as much wood as a woodchuck could if...
# Response 17: It’s a tongue‑twister, not a math problem, but the most comm...
# Response 6: That’s the classic tongue‑twister that never has a scientifi...
# Response 4: The classic answer is a playful one‑sentence rhyme, but let’...
# Response 2: **Answer:**
# There’s no hard‑wired “exact” number, but if a...
# Response 9: **Answer (tongue‑twister style):**
# > “If a woodchuck could...
# Response 7: Ah, the age‑old riddle that’s been the subject of lullabies,...
# Response 8: Ah, the classic tongue‑twister that’s been made to grind lin...
# Response 10: **Answer:**
# A wood‑chuck could chuck *about 700 pounds* of...
# Response 14: **Answer (in the style of the classic tongue‑twister):**
#
# > ...
# Response 15: Ah, the age‑old tongue‑twister that has bugged linguists, wo...
# Response 22: **Answer (the classic tongue‑twister answer)**
# A wood‑chuc...
# Response 11: **Short answer:** About **700 pounds (≈320 kg) of wood**—by ...
# Response 19: **Short answer**
#
# > A typical woodchuck (ground‑hog) wouldn’...
# Response 16: **Short answer:** Roughly **700 pounds (about 320 kg)** of w...
# Response 5: Ah, the old wood‑chuck conundrum—a riddle that has tickled m...
# Response 20: The short answer is—**we don’t really know**.
# It’s a playf...
